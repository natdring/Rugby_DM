# %% [markdown]
# # Data Collection
#
# Needed to gather historical data regarding player, teams, etc.
#
# Fortunately, [ESPN Scrum](espnscrum.com) provides a data on players, teams, and matches going back to 1896.
#
# Using a scrapy spider built by peloyeje (found [here](https://github.com/peloyeje/map536-rugby-data-scraper)), it was possible to collect a meaningful sample of matches and results, along with player stats for each match to work with.
#
# Additionally, the World Rugby rankings were gathered from World Rugby's website using Beautiful Soup.

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("rankings.csv")

data
# Out:
#              team_name abbreviation  num_matches        pts  pos   prev_pts  \
# 0              England          ENG           11  89.948520    1  89.948520
# 1          New Zealand          NZL           11  89.797710    2  89.797710
# 2            Australia          AUS           11  84.762690    3  83.805620
# 3              Ireland          IRE           11  83.924580    4  83.924580
# 4               France          FRA           11  82.845314    5  82.845314
# ...                ...          ...          ...        ...  ...        ...
# 577110          Monaco          MON           12  23.171558  101  23.171558
# 577111          Greece          GRE           17  22.546452  102  22.546452
# 577112       Indonesia          INA            5  21.891422  103  21.891422
# 577113         Vanuatu          VAN           16  21.453693  104  21.453693
# 577114  American Samoa          ASA           13  19.532106  105  19.532106
#
#         prev_pos        date
# 0              1  2003-10-13
# 1              2  2003-10-13
# 2              4  2003-10-13
# 3              3  2003-10-13
# 4              5  2003-10-13
# ...          ...         ...
# 577110       101  2019-11-14
# 577111       102  2019-11-14
# 577112       103  2019-11-14
# 577113       104  2019-11-14
# 577114       105  2019-11-14
#
# [577115 rows x 8 columns]

# %%
fig = plt.figure(figsize=(18, 18))

for abbr in data.loc[data.pos < 4].abbreviation.unique():
    abbr_pts = data.loc[data.abbreviation == abbr].values[:,[3]]
    plt.plot(abbr_pts, label = abbr)
    
plt.title("Points of Top 3 Ranked Countries Since 2003")
plt.xlabel("Entry #")
plt.ylabel("Points")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(18, 18))
#print(data.loc[data.pos < 4].abbreviation.unique())

print(data.loc[data.abbreviation== abbr].values[:,[3]])

for abbr in data.loc[data.pos < 4].abbreviation.unique():
    #print(data.loc[data.abbreviation== abbr].values[:, [7]])
    abbr_pts = data.loc[data.abbreviation == abbr].values[:,[3]]
    #print(abbr_pts)
    summation = 0
    for item in abbr_pts:
        summation += item
    plt.plot(summation, label = abbr)
    
#print()
#print(abbr_pts[0])
    
plt.title("Summation of points of Top 3 Ranked Countries Since 2003.")
plt.xlabel("Entry #")
plt.ylabel("Summation of Points")
plt.legend()
plt.show()

#list = [['2003-10-13'], ['2003-10-14'], ['2003-10-15'], ['2019-11-12'], ['2019-11-13'], ['2019-11-14']]

#year = '2003'
#for item in list:
#  if(item[0][0:4] != year):
#    continue
#  print(item[0])
# Out:
# [[74.82875]
#  [74.82875]
#  [74.82875]
#  ...
#  [85.020935]
#  [85.020935]
#  [85.020935]]
